# %% [markdown]
# # Extract airport and seaport codes from uktradeinfo.com Port_codes spreadsheet
#
# > The air and seaport codes are for use when completing Customs documentation for UK trade with countries outside the European Union.
#
# > The codes are to be used to complete the Location of Goods box (Box 30 of the SAD).
#
# > There are two types of airports - Designated Airports and Non-designated. Non-designated Airports are those with a Certificate of Agreement (CoA) or a military base operating under a Memorandum of Understanding (MoU) or Agreement (MoA).
#
# > Seaports in upper case are trade ports for which trade statistics are available. Ports in lower case are not identified separately for trade statistics purposes, but their trade is included in the statistics for the ports shown in upper case.

# %% [markdown]
# Load the Excel spreadsheet and store a copy locally

# %%
from databaker.framework import *
import requests
import json
from pathlib import Path
from collections import defaultdict
from string import capwords

ports_file = Path('in/Port_codes.xls')
if not (ports_file.exists() and ports_file.is_file()):
    response = requests.get('https://www.uktradeinfo.com/CodesAndGuides/Documents/Port_codes.xls')
    with open(ports_file, 'wb') as f:
        f.write(response.content)

sheets = loadxlstabs(ports_file)
# Out:
# Loading in/Port_codes.xls which has size 110080 bytes
# Table names: ['Information', 'Airport codes', 'Seaport codes', 'Other codes']

# %% [markdown]
# The first tab/sheet is a description and the second tab should be named 'Airport codes'.
#
# The 'alpha codes' are the International Air Transport Association (IATA) airport codes, which we'll use as the identity for each airport. We'll collect the rest of the information for each airport as is and output a JSON representation for further processing.

# %%
assert len(sheets) == 4
airport_codes = sheets[1]
assert airport_codes.name == 'Airport codes'

airports = [
    {
        '@id': airport.shift(RIGHT).value,
        '@type': airport.shift(RIGHT).shift(RIGHT).shift(RIGHT).value,
        'label': airport.value,
        'code': airport.shift(RIGHT).value,
        'seq': airport.shift(RIGHT).shift(RIGHT).value
    } for airport in airport_codes.excel_ref('A1').fill(DOWN)
]

print(json.dumps(airports, indent=2))
# Out:
# [
#   {
#     "@id": "ABZ",
#     "@type": "Designated",
#     "label": "Aberdeen Airport",
#     "code": "ABZ",
#     "seq": "449"
#   },
#   {
#     "@id": "AOA",
#     "@type": "Not applicable",
#     "label": "All Other Airports",
#     "code": "AOA",
#     "seq": "481"
#   },
#   {
#     "@id": "BFS",
#     "@type": "Designated",
#     "label": "Belfast International Airport",
#     "code": "BFS",
#     "seq": "427"
#   },
#   {
#     "@id": "BQH",
#     "@type": "Designated",
#     "label": "Biggin Hill Airport",
#     "code": "BQH",
#     "seq": "474"
#   },
#   {
#     "@id": "BHX",
#     "@type": "Designated",
#     "label": "Birmingham Airport",
#     "code": "BHX",
#     "seq": "433"
#   },
#   {
#     "@id": "BLK",
#     "@type": "Designated",
#     "label": "Blackpool International Airport",
#     "code": "BLK",
#     "seq": "459"
#   },
#   {
#     "@id": "BOH",
#     "@type": "Designated",
#     "label": "Bournemouth (Hurn) Airport",
#     "code": "BOH",
#     "seq": "441"
#   },
#   {
#     "@id": "BRS",
#     "@type": "Designated",
#     "label": "Bristol Airport",
#     "code": "BRS",
#     "seq": "438"
#   },
#   {
#     "@id": "BZN",
#     "@type": "Military",
#     "label": "Brize Norton",
#     "code": "BZN",
#     "seq": "426"
#   },
#   {
#     "@id": "CBG",
#     "@type": "Designated",
#     "label": "Cambridge Airport",
#     "code": "CBG",
#     "seq": "453"
#   },
#   {
#     "@id": "CWL",
#     "@type": "Designated",
#     "label": "Cardiff (Wales) Airport",
#     "code": "CWL",
#     "seq": "439"
#   },
#   {
#     "@id": "CVT",
#     "@type": "Designated",
#     "label": "Coventry Airport",
#     "code": "CVT",
#     "seq": "458"
#   },
#   {
#     "@id": "MME",
#     "@type": "Designated",
#     "label": "Durham Tees Valley (Teeside) Airport",
#     "code": "MME",
#     "seq": "447"
#   },
#   {
#     "@id": "EMA",
#     "@type": "Designated",
#     "label": "East Midlands Airport",
#     "code": "EMA",
#     "seq": "437"
#   },
#   {
#     "@id": "EDI",
#     "@type": "Designated",
#     "label": "Edinburgh Airport",
#     "code": "EDI",
#     "seq": "448"
#   },
#   {
#     "@id": "EXT",
#     "@type": "Designated",
#     "label": "Exeter Airport",
#     "code": "EXT",
#     "seq": "440"
#   },
#   {
#     "@id": "FFD",
#     "@type": "Military",
#     "label": "Fairford",
#     "code": "FFD",
#     "seq": "465"
#   },
#   {
#     "@id": "FAB",
#     "@type": "Designated",
#     "label": "Farnborough Airport",
#     "code": "FAB",
#     "seq": "477"
#   },
#   {
#     "@id": "FLT",
#     "@type": "Military",
#     "label": "Feltwell",
#     "code": "FLT",
#     "seq": "460"
#   },
#   {
#     "@id": "FZO",
#     "@type": "Designated",
#     "label": "Filton Aerodrome (Bristol)",
#     "code": "FZO",
#     "seq": "475"
#   },
#   {
#     "@id": "BHD",
#     "@type": "Non-designated",
#     "label": "George Best Belfast City Airport",
#     "code": "BHD",
#     "seq": "454"
#   },
#   {
#     "@id": "GLA",
#     "@type": "Designated",
#     "label": "Glasgow Airport",
#     "code": "GLA",
#     "seq": "450"
#   },
#   {
#     "@id": "GLO",
#     "@type": "Non-designated",
#     "label": "Gloucester (Staverton) Airport",
#     "code": "GLO",
#     "seq": "467"
#   },
#   {
#     "@id": "HUY",
#     "@type": "Designated",
#     "label": "Humberside International Airport",
#     "code": "HUY",
#     "seq": "457"
#   },
#   {
#     "@id": "KEM",
#     "@type": "Non-designated",
#     "label": "Kemble Airport",
#     "code": "KEM",
#     "seq": "468"
#   },
#   {
#     "@id": "LKH",
#     "@type": "Military",
#     "label": "Lakenheath",
#     "code": "LKH",
#     "seq": "464"
#   },
#   {
#     "@id": "LAS",
#     "@type": "Non-designated",
#     "label": "Lasham Airport",
#     "code": "LAS",
#     "seq": "451"
#   },
#   {
#     "@id": "LBA",
#     "@type": "Designated",
#     "label": "Leeds Bradford Airport",
#     "code": "LBA",
#     "seq": "445"
#   },
#   {
#     "@id": "LPL",
#     "@type": "Designated",
#     "label": "Liverpool John Lennon Airport",
#     "code": "LPL",
#     "seq": "444"
#   },
#   {
#     "@id": "LYD",
#     "@type": "Designated",
#     "label": "London Ashford (Lydd) Airport",
#     "code": "LYD",
#     "seq": "470"
#   },
#   {
#     "@id": "LCY",
#     "@type": "Designated",
#     "label": "London City Airport",
#     "code": "LCY",
#     "seq": "456"
#   },
#   {
#     "@id": "LGW",
#     "@type": "Designated",
#     "label": "London Gatwick Airport",
#     "code": "LGW",
#     "seq": "429"
#   },
#   {
#     "@id": "LHR",
#     "@type": "Designated",
#     "label": "London Heathrow Airport",
#     "code": "LHR",
#     "seq": "428"
#   },
#   {
#     "@id": "LTN",
#     "@type": "Designated",
#     "label": "London Luton Airport",
#     "code": "LTN",
#     "seq": "436"
#   },
#   {
#     "@id": "LSA",
#     "@type": "Designated",
#     "label": "London Stansted Airport",
#     "code": "LSA",
#     "seq": "434"
#   },
#   {
#     "@id": "LYH",
#     "@type": "Military",
#     "label": "Lyneham",
#     "code": "LYH",
#     "seq": "466"
#   },
#   {
#     "@id": "MAN",
#     "@type": "Designated",
#     "label": "Manchester Airport",
#     "code": "MAN",
#     "seq": "430"
#   },
#   {
#     "@id": "MSE",
#     "@type": "Designated",
#     "label": "Manston Airport",
#     "code": "MSE",
#     "seq": "476"
#   },
#   {
#     "@id": "MWH",
#     "@type": "Military",
#     "label": "Menwith Hill",
#     "code": "MWH",
#     "seq": "462"
#   },
#   {
#     "@id": "MDH",
#     "@type": "Military",
#     "label": "Mildenhall",
#     "code": "MDH",
#     "seq": "463"
#   },
#   {
#     "@id": "MLS",
#     "@type": "Military",
#     "label": "Moleshill",
#     "code": "MLS",
#     "seq": "461"
#   },
#   {
#     "@id": "NCL",
#     "@type": "Designated",
#     "label": "Newcastle Airport",
#     "code": "NCL",
#     "seq": "446"
#   },
#   {
#     "@id": "NQY",
#     "@type": "Designated",
#     "label": "Newquay Airport",
#     "code": "NQY",
#     "seq": "478"
#   },
#   {
#     "@id": "NWI",
#     "@type": "Designated",
#     "label": "Norwich Airport",
#     "code": "NWI",
#     "seq": "443"
#   },
#   {
#     "@id": "OSA",
#     "@type": "Not applicable",
#     "label": "Other Scottish Airports",
#     "code": "OSA",
#     "seq": "480"
#   },
#   {
#     "@id": "OAK",
#     "@type": "Non-designated",
#     "label": "Oxford Airport (Kidlington)",
#     "code": "OAK",
#     "seq": "452"
#   },
#   {
#     "@id": "PLH",
#     "@type": "Designated",
#     "label": "Plymouth Airport",
#     "code": "PLH",
#     "seq": "471"
#   },
#   {
#     "@id": "PIK",
#     "@type": "Designated",
#     "label": "Prestwick Airport",
#     "code": "PIK",
#     "seq": "431"
#   },
#   {
#     "@id": "RAF",
#     "@type": "Military",
#     "label": "RAF Bases",
#     "code": "RAF",
#     "seq": "469"
#   },
#   {
#     "@id": "DSA",
#     "@type": "Non-designated",
#     "label": "Robin Hood Doncaster Sheffield",
#     "code": "DSA",
#     "seq": "455"
#   },
#   {
#     "@id": "RWY",
#     "@type": "Designated",
#     "label": "Ronaldsway Airport (IoM)",
#     "code": "RWY",
#     "seq": "435"
#   },
#   {
#     "@id": "ESH",
#     "@type": "Designated",
#     "label": "Shoreham Airport",
#     "code": "ESH",
#     "seq": "472"
#   },
#   {
#     "@id": "SOU",
#     "@type": "Designated",
#     "label": "Southampton (Eastleigh) Airport",
#     "code": "SOU",
#     "seq": "442"
#   },
#   {
#     "@id": "SEN",
#     "@type": "Designated",
#     "label": "Southend Airport",
#     "code": "SEN",
#     "seq": "432"
#   },
#   {
#     "@id": "STY",
#     "@type": "Non-designated",
#     "label": "Stornoway Airport",
#     "code": "STY",
#     "seq": "442"
#   },
#   {
#     "@id": "LSI",
#     "@type": "Designated",
#     "label": "Sumburgh Airport (Shetland)",
#     "code": "LSI",
#     "seq": "473"
#   },
#   {
#     "@id": "WAR",
#     "@type": "Non-designated",
#     "label": "Warton Aerodrome",
#     "code": "WAR",
#     "seq": "479"
#   },
#   {
#     "@id": "YVL",
#     "@type": "Non-designated",
#     "label": "Yeovil Aerodrome",
#     "code": "YVL",
#     "seq": "482"
#   }
# ]

# %% [markdown]
# Put this into a JSON-LD structure and output.

# %%
airports_context = {
    "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
    "schema": "http://schema.org/",
    "ports": "https://www.uktradeinfo.com/def/ports#",
    "iata": "schema:iataCode",
    "label": "rdfs:label",
    "seq": "ukti:sequence",
    "@base": "https://www.uktradeinfo.com/id/airports/",
    "Designated": "ports:DesignatedAirport",
    "Non-designated": "ports:NonDesignatedAirport",
    "Military": "ports:MilitaryAirport",
    "Not applicable": "ports:NotApplicable"
}

json_ld = {"@context": airports_context, "@graph": airports}
with open('out/airports.jsonld', 'w') as airports_file:
    json.dump(json_ld, airports_file, indent=2)

# %% [markdown]
# The next tab is for seaports. There's more information codified in this table, e.g. a label all in uppercase means that this is the canonical name for the various ports that the statistics will be grouped together into.
#
# The JSON output captures this, using the alpha code as the primary ID and each record can then list the labels of the ports that are included in this group, if any.

# %%
seaport_codes = sheets[2]
assert seaport_codes.name == 'Seaport codes'

seaports = defaultdict(dict)
for seaport in seaport_codes.excel_ref('A1').fill(DOWN):
    label = seaport.value
    alpha = seaport.shift(RIGHT).value
    seq = seaport.shift(RIGHT).shift(RIGHT).value
    location = seaport.shift(RIGHT).shift(RIGHT).shift(RIGHT).value
    comment = seaport.shift(RIGHT).shift(RIGHT).shift(RIGHT).shift(RIGHT).value
    
    if 'seq' in seaports[alpha]:
        assert seaports[alpha]['seq'] == seq
    else:
        seaports[alpha]['seq'] = seq
    
    if location != 'Not applicable':
        if 'location' in seaports[alpha]:
            assert seaports[alpha]['location'] == location
        else:
            seaports[alpha]['location'] = location
    
    if comment != "":
        if 'comment' in seaports[alpha]:
            assert seaports[alpha]['comment'] == comment
        else:
            seaports[alpha]['comment'] = comment

    if label.isupper():
        seaports[alpha]['label'] = capwords(label)
    else:
        newport = {"@id": label.lower().replace(' ', '_'), "label": label, "@type": "seaport"}
        if 'includes' in seaports[alpha]:
            seaports[alpha]['includes'].append(newport)
        else:
            seaports[alpha]['includes'] = [newport]

seaports_list = [ {**v, '@id': k, '@type': 'trade'} for (k, v) in seaports.items() ]

print(json.dumps(seaports_list, indent=2))
# Out:
# [
#   {
#     "seq": "164",
#     "location": "Scotland",
#     "label": "Aberdeen",
#     "@id": "ABD",
#     "@type": "trade"
#   },
#   {
#     "seq": "203",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "althorpe",
#         "label": "Althorpe",
#         "@type": "seaport"
#       },
#       {
#         "@id": "beckingham",
#         "label": "Beckingham",
#         "@type": "seaport"
#       },
#       {
#         "@id": "burton_stather",
#         "label": "Burton Stather",
#         "@type": "seaport"
#       },
#       {
#         "@id": "flixborough_wharf",
#         "label": "Flixborough Wharf",
#         "@type": "seaport"
#       },
#       {
#         "@id": "gainsborough",
#         "label": "Gainsborough",
#         "@type": "seaport"
#       },
#       {
#         "@id": "grove_wharves",
#         "label": "Grove Wharves",
#         "@type": "seaport"
#       },
#       {
#         "@id": "guness_wharf",
#         "label": "Guness Wharf",
#         "@type": "seaport"
#       },
#       {
#         "@id": "keadby",
#         "label": "Keadby",
#         "@type": "seaport"
#       },
#       {
#         "@id": "neap_house",
#         "label": "Neap House",
#         "@type": "seaport"
#       },
#       {
#         "@id": "point_bid",
#         "label": "Point BID",
#         "@type": "seaport"
#       },
#       {
#         "@id": "scunthorpe",
#         "label": "Scunthorpe",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Trent",
#     "@id": "TRT",
#     "@type": "trade"
#   },
#   {
#     "seq": "176",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "amble",
#         "label": "Amble",
#         "@type": "seaport"
#       },
#       {
#         "@id": "berwick",
#         "label": "Berwick",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Blyth",
#     "@id": "BLY",
#     "@type": "trade"
#   },
#   {
#     "seq": "154",
#     "location": "Scotland",
#     "includes": [
#       {
#         "@id": "annan",
#         "label": "Annan",
#         "@type": "seaport"
#       },
#       {
#         "@id": "barcaldine",
#         "label": "Barcaldine",
#         "@type": "seaport"
#       },
#       {
#         "@id": "campbeltown",
#         "label": "Campbeltown",
#         "@type": "seaport"
#       },
#       {
#         "@id": "faslane",
#         "label": "Faslane",
#         "@type": "seaport"
#       },
#       {
#         "@id": "finnart",
#         "label": "Finnart",
#         "@type": "seaport"
#       },
#       {
#         "@id": "furnace",
#         "label": "Furnace",
#         "@type": "seaport"
#       },
#       {
#         "@id": "garlieston",
#         "label": "Garlieston",
#         "@type": "seaport"
#       },
#       {
#         "@id": "hunterston",
#         "label": "Hunterston",
#         "@type": "seaport"
#       },
#       {
#         "@id": "islay",
#         "label": "Islay",
#         "@type": "seaport"
#       },
#       {
#         "@id": "oban",
#         "label": "Oban",
#         "@type": "seaport"
#       },
#       {
#         "@id": "palnackie",
#         "label": "Palnackie",
#         "@type": "seaport"
#       },
#       {
#         "@id": "stranraer",
#         "label": "Stranraer",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Greenock",
#     "@id": "GRK",
#     "@type": "trade"
#   },
#   {
#     "seq": "076",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "appledore",
#         "label": "Appledore",
#         "@type": "seaport"
#       },
#       {
#         "@id": "bideford",
#         "label": "Bideford",
#         "@type": "seaport"
#       },
#       {
#         "@id": "bridgwater",
#         "label": "Bridgwater",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Watchet",
#     "@id": "WAT",
#     "@type": "trade"
#   },
#   {
#     "seq": "166",
#     "location": "Scotland",
#     "includes": [
#       {
#         "@id": "arbroath",
#         "label": "Arbroath",
#         "@type": "seaport"
#       },
#       {
#         "@id": "perth",
#         "label": "Perth",
#         "@type": "seaport"
#       },
#       {
#         "@id": "tayport",
#         "label": "Tayport",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Dundee",
#     "@id": "DUN",
#     "@type": "trade"
#   },
#   {
#     "seq": "153",
#     "location": "Scotland",
#     "label": "Ardrossan",
#     "@id": "ARD",
#     "@type": "trade"
#   },
#   {
#     "seq": "077",
#     "location": "England & Wales",
#     "label": "Avonmouth",
#     "includes": [
#       {
#         "@id": "portishead",
#         "label": "Portishead",
#         "@type": "seaport"
#       },
#       {
#         "@id": "royal_portbury_dock",
#         "label": "Royal Portbury Dock",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "AVO",
#     "@type": "trade"
#   },
#   {
#     "seq": "151",
#     "location": "Scotland",
#     "label": "Ayr",
#     "includes": [
#       {
#         "@id": "girvan",
#         "label": "Girvan",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "AYR",
#     "@type": "trade"
#   },
#   {
#     "seq": "001",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "baltic_wharf,_rochford",
#         "label": "Baltic Wharf, Rochford",
#         "@type": "seaport"
#       },
#       {
#         "@id": "holehaven",
#         "label": "Holehaven",
#         "@type": "seaport"
#       },
#       {
#         "@id": "leigh-on-sea",
#         "label": "Leigh-on-Sea",
#         "@type": "seaport"
#       },
#       {
#         "@id": "rochford",
#         "label": "Rochford",
#         "@type": "seaport"
#       },
#       {
#         "@id": "southend_(corporation_jetty)",
#         "label": "Southend (Corporation Jetty)",
#         "@type": "seaport"
#       },
#       {
#         "@id": "tilbury",
#         "label": "Tilbury",
#         "@type": "seaport"
#       }
#     ],
#     "label": "London",
#     "@id": "LON",
#     "@type": "trade"
#   },
#   {
#     "seq": "134",
#     "location": "England & Wales",
#     "label": "Barrow-in-furness",
#     "includes": [
#       {
#         "@id": "millom",
#         "label": "Millom",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "BAR",
#     "@type": "trade"
#   },
#   {
#     "seq": "204",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "barrow-on-humber",
#         "label": "Barrow-on-Humber",
#         "@type": "seaport"
#       },
#       {
#         "@id": "barton-on-humber",
#         "label": "Barton-on-Humber",
#         "@type": "seaport"
#       },
#       {
#         "@id": "killingholme",
#         "label": "Killingholme",
#         "@type": "seaport"
#       },
#       {
#         "@id": "new_holland",
#         "label": "New Holland",
#         "@type": "seaport"
#       },
#       {
#         "@id": "south_killingholme_jetty",
#         "label": "South Killingholme Jetty",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Immingham",
#     "@id": "IMM",
#     "@type": "trade"
#   },
#   {
#     "seq": "080",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "barry_dock",
#         "label": "Barry DocK",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Cardiff",
#     "@id": "CDF",
#     "@type": "trade"
#   },
#   {
#     "seq": "301",
#     "location": "Northern Ireland",
#     "label": "Belfast",
#     "includes": [
#       {
#         "@id": "larne",
#         "label": "Larne",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "BEL",
#     "@type": "trade"
#   },
#   {
#     "seq": "131",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "birkenhead",
#         "label": "Birkenhead",
#         "@type": "seaport"
#       },
#       {
#         "@id": "garston",
#         "label": "Garston",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Liverpool",
#     "@id": "LIV",
#     "@type": "trade"
#   },
#   {
#     "seq": "226",
#     "location": "England & Wales",
#     "label": "Boston",
#     "@id": "BOS",
#     "@type": "trade"
#   },
#   {
#     "seq": "155",
#     "location": "Scotland",
#     "includes": [
#       {
#         "@id": "bowling",
#         "label": "Bowling",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Glasgow",
#     "@id": "GLW",
#     "@type": "trade"
#   },
#   {
#     "seq": "169",
#     "location": "Scotland",
#     "includes": [
#       {
#         "@id": "braefoot_bay",
#         "label": "Braefoot Bay",
#         "@type": "seaport"
#       },
#       {
#         "@id": "burntisland",
#         "label": "Burntisland",
#         "@type": "seaport"
#       },
#       {
#         "@id": "inverkeithing",
#         "label": "Inverkeithing",
#         "@type": "seaport"
#       },
#       {
#         "@id": "methil",
#         "label": "Methil",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Grangemouth",
#     "@id": "GRG",
#     "@type": "trade"
#   },
#   {
#     "seq": "201",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "bridlington",
#         "label": "Bridlington",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Hull",
#     "@id": "HUL",
#     "@type": "trade"
#   },
#   {
#     "seq": "052",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "bridport",
#         "label": "Bridport",
#         "@type": "seaport"
#       },
#       {
#         "@id": "portland",
#         "label": "Portland",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Weymouth",
#     "@id": "WEY",
#     "@type": "trade"
#   },
#   {
#     "seq": "002",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "brightlingsea",
#         "label": "Brightlingsea",
#         "@type": "seaport"
#       },
#       {
#         "@id": "burnham-on-crouch",
#         "label": "Burnham-on-Crouch",
#         "@type": "seaport"
#       },
#       {
#         "@id": "fingringhoe",
#         "label": "Fingringhoe",
#         "@type": "seaport"
#       },
#       {
#         "@id": "maldon",
#         "label": "Maldon",
#         "@type": "seaport"
#       },
#       {
#         "@id": "rowhedge",
#         "label": "Rowhedge",
#         "@type": "seaport"
#       },
#       {
#         "@id": "wivenhoe",
#         "label": "Wivenhoe",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Colchester",
#     "@id": "COL",
#     "@type": "trade"
#   },
#   {
#     "seq": "081",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "briton_ferry",
#         "label": "Briton Ferry",
#         "@type": "seaport"
#       },
#       {
#         "@id": "neath_abbey",
#         "label": "Neath Abbey",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Port Talbot",
#     "@id": "PTB",
#     "@type": "trade"
#   },
#   {
#     "seq": "054",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "brixham",
#         "label": "Brixham",
#         "@type": "seaport"
#       },
#       {
#         "@id": "dartmouth",
#         "label": "Dartmouth",
#         "@type": "seaport"
#       },
#       {
#         "@id": "torquay",
#         "label": "Torquay",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Teignmouth",
#     "@id": "TNM",
#     "@type": "trade"
#   },
#   {
#     "seq": "162",
#     "location": "Scotland",
#     "includes": [
#       {
#         "@id": "buckie",
#         "label": "Buckie",
#         "@type": "seaport"
#       },
#       {
#         "@id": "macduff",
#         "label": "Macduff",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Fraserburgh",
#     "@id": "FRB",
#     "@type": "trade"
#   },
#   {
#     "seq": "161",
#     "location": "Scotland",
#     "includes": [
#       {
#         "@id": "burghead",
#         "label": "Burghead",
#         "@type": "seaport"
#       },
#       {
#         "@id": "corpach,_incl._annat_pier",
#         "label": "Corpach, incl. Annat Pier",
#         "@type": "seaport"
#       },
#       {
#         "@id": "lochaline",
#         "label": "Lochaline",
#         "@type": "seaport"
#       },
#       {
#         "@id": "lossiemouth",
#         "label": "Lossiemouth",
#         "@type": "seaport"
#       },
#       {
#         "@id": "scrabster",
#         "label": "Scrabster",
#         "@type": "seaport"
#       },
#       {
#         "@id": "ullapool",
#         "label": "Ullapool",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Inverness",
#     "@id": "INV",
#     "@type": "trade"
#   },
#   {
#     "seq": "103",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "caernarfon",
#         "label": "Caernarfon",
#         "@type": "seaport"
#       },
#       {
#         "@id": "port_penrhyn",
#         "label": "Port Penrhyn",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Llanddulas",
#     "@id": "LLA",
#     "@type": "trade"
#   },
#   {
#     "seq": "326",
#     "location": "Isle of Man",
#     "includes": [
#       {
#         "@id": "castletown",
#         "label": "Castletown",
#         "@type": "seaport"
#       },
#       {
#         "@id": "peel",
#         "label": "Peel",
#         "@type": "seaport"
#       },
#       {
#         "@id": "ramsey",
#         "label": "Ramsey",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Douglas",
#     "@id": "DGS",
#     "@type": "trade"
#   },
#   {
#     "seq": "424",
#     "location": "Channel Tunnel",
#     "label": "Channel Fixed Link",
#     "@id": "CFL",
#     "@type": "trade"
#   },
#   {
#     "seq": "056",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "charlestown",
#         "label": "Charlestown",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Fowey",
#     "@id": "FOY",
#     "@type": "trade"
#   },
#   {
#     "seq": "079",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "chepstow",
#         "label": "Chepstow",
#         "@type": "seaport"
#       },
#       {
#         "@id": "newport,_gwent",
#         "label": "NEWPORT, Gwent",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "NPT",
#     "@type": "trade"
#   },
#   {
#     "seq": "302",
#     "location": "Northern Ireland",
#     "label": "Coleraine",
#     "includes": [
#       {
#         "@id": "portrush",
#         "label": "Portrush",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "CLR",
#     "@type": "trade"
#   },
#   {
#     "seq": "490",
#     "comment": "Not to be used when completing declarations.",
#     "includes": [
#       {
#         "@id": "continental_shelf_(uk_part)",
#         "label": "Continental Shelf (UK Part)",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "WWW",
#     "@type": "trade"
#   },
#   {
#     "seq": "030",
#     "location": "England & Wales",
#     "label": "Cowes",
#     "@id": "COW",
#     "@type": "trade"
#   },
#   {
#     "seq": "007",
#     "location": "England & Wales",
#     "label": "Dover",
#     "@id": "DOV",
#     "@type": "trade"
#   },
#   {
#     "seq": "126",
#     "location": "England & Wales",
#     "label": "Ellesmere Port",
#     "@id": "ELL",
#     "@type": "trade"
#   },
#   {
#     "seq": "053",
#     "location": "England & Wales",
#     "label": "Exeter",
#     "includes": [
#       {
#         "@id": "exmouth",
#         "label": "Exmouth",
#         "@type": "seaport"
#       },
#       {
#         "@id": "topsham",
#         "label": "Topsham",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "EXE",
#     "@type": "trade"
#   },
#   {
#     "seq": "058",
#     "location": "England & Wales",
#     "label": "Falmouth",
#     "includes": [
#       {
#         "@id": "penryn",
#         "label": "Penryn",
#         "@type": "seaport"
#       },
#       {
#         "@id": "truro",
#         "label": "Truro",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "FAL",
#     "@type": "trade"
#   },
#   {
#     "seq": "005",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "faversham",
#         "label": "Faversham",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Whitstable",
#     "@id": "WTS",
#     "@type": "trade"
#   },
#   {
#     "seq": "251",
#     "location": "England & Wales",
#     "label": "Felixstowe",
#     "@id": "FXT",
#     "@type": "trade"
#   },
#   {
#     "seq": "102",
#     "location": "England & Wales",
#     "label": "Fishguard",
#     "@id": "FIS",
#     "@type": "trade"
#   },
#   {
#     "seq": "132",
#     "location": "England & Wales",
#     "label": "Fleetwood",
#     "@id": "FLE",
#     "@type": "trade"
#   },
#   {
#     "seq": "008",
#     "location": "England & Wales",
#     "label": "Folkestone",
#     "includes": [
#       {
#         "@id": "rye",
#         "label": "Rye",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "FOL",
#     "@type": "trade"
#   },
#   {
#     "seq": "494",
#     "comment": "Not to be used when completing declarations.",
#     "includes": [
#       {
#         "@id": "freezones",
#         "label": "Freezones",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "FRZ",
#     "@type": "trade"
#   },
#   {
#     "seq": "133",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "glasson_dock",
#         "label": "Glasson Dock",
#         "@type": "seaport"
#       },
#       {
#         "@id": "lancaster",
#         "label": "Lancaster",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Heysham",
#     "@id": "HEY",
#     "@type": "trade"
#   },
#   {
#     "seq": "078",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "gloucester",
#         "label": "Gloucester",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Sharpness",
#     "@id": "SSS",
#     "@type": "trade"
#   },
#   {
#     "seq": "202",
#     "location": "England & Wales",
#     "label": "Goole",
#     "includes": [
#       {
#         "@id": "howdendyke",
#         "label": "Howdendyke",
#         "@type": "seaport"
#       },
#       {
#         "@id": "selby",
#         "label": "Selby",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "GOO",
#     "@type": "trade"
#   },
#   {
#     "seq": "229",
#     "location": "England & Wales",
#     "label": "Great Yarmouth",
#     "@id": "GTY",
#     "@type": "trade"
#   },
#   {
#     "seq": "205",
#     "location": "England & Wales",
#     "label": "Grimsby",
#     "@id": "GRI",
#     "@type": "trade"
#   },
#   {
#     "seq": "179",
#     "location": "England & Wales",
#     "label": "Hartlepool",
#     "@id": "HTP",
#     "@type": "trade"
#   },
#   {
#     "seq": "253",
#     "location": "England & Wales",
#     "label": "Harwich",
#     "includes": [
#       {
#         "@id": "mistley",
#         "label": "Mistley",
#         "@type": "seaport"
#       },
#       {
#         "@id": "parkeston_quay",
#         "label": "Parkeston Quay",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "HRH",
#     "@type": "trade"
#   },
#   {
#     "seq": "104",
#     "location": "England & Wales",
#     "label": "Holyhead",
#     "@id": "HLD",
#     "@type": "trade"
#   },
#   {
#     "seq": "172",
#     "location": "Scotland",
#     "label": "Hound Point Terminal",
#     "@id": "HPT",
#     "@type": "trade"
#   },
#   {
#     "seq": "495",
#     "comment": "Not to be used when completing declarations.",
#     "includes": [
#       {
#         "@id": "inland_clearance",
#         "label": "Inland Clearance",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "ZLC",
#     "@type": "trade"
#   },
#   {
#     "seq": "184",
#     "location": "Scotland",
#     "label": "Invergordon",
#     "@id": "IVG",
#     "@type": "trade"
#   },
#   {
#     "seq": "252",
#     "location": "England & Wales",
#     "label": "Ipswich",
#     "@id": "IPS",
#     "@type": "trade"
#   },
#   {
#     "seq": "152",
#     "location": "Scotland",
#     "label": "Irvine",
#     "@id": "IRV",
#     "@type": "trade"
#   },
#   {
#     "seq": "228",
#     "location": "England & Wales",
#     "label": "Kings Lynn",
#     "includes": [
#       {
#         "@id": "wells",
#         "label": "Wells",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "KLN",
#     "@type": "trade"
#   },
#   {
#     "seq": "168",
#     "location": "Scotland",
#     "label": "Kirkcaldy",
#     "@id": "KKD",
#     "@type": "trade"
#   },
#   {
#     "seq": "159",
#     "location": "Scotland",
#     "label": "Kirkwall",
#     "includes": [
#       {
#         "@id": "stromness",
#         "label": "Stromness",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "KWL",
#     "@type": "trade"
#   },
#   {
#     "seq": "170",
#     "location": "Scotland",
#     "label": "Leith",
#     "@id": "LEI",
#     "@type": "trade"
#   },
#   {
#     "seq": "160",
#     "location": "Scotland",
#     "label": "Lerwick",
#     "includes": [
#       {
#         "@id": "scalloway",
#         "label": "Scalloway",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "LER",
#     "@type": "trade"
#   },
#   {
#     "seq": "027",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "littlehampton",
#         "label": "Littlehampton",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Shoreham",
#     "@id": "SHO",
#     "@type": "trade"
#   },
#   {
#     "seq": "082",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "llanelli",
#         "label": "Llanelli",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Swansea",
#     "@id": "SWA",
#     "@type": "trade"
#   },
#   {
#     "seq": "010",
#     "location": "England & Wales",
#     "label": "London Gateway",
#     "@id": "LGP",
#     "@type": "trade"
#   },
#   {
#     "seq": "303",
#     "location": "Northern Ireland",
#     "label": "Londonderry",
#     "@id": "LDY",
#     "@type": "trade"
#   },
#   {
#     "seq": "492",
#     "comment": "Not to be used when completing declarations.",
#     "includes": [
#       {
#         "@id": "low_value_trade",
#         "label": "Low Value Trade",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "ZYY",
#     "@type": "trade"
#   },
#   {
#     "seq": "230",
#     "location": "England & Wales",
#     "label": "Lowestoft",
#     "@id": "LOW",
#     "@type": "trade"
#   },
#   {
#     "seq": "029",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "lymington",
#         "label": "Lymington",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Southampton",
#     "@id": "STN",
#     "@type": "trade"
#   },
#   {
#     "seq": "129",
#     "location": "England & Wales",
#     "label": "Manchester",
#     "includes": [
#       {
#         "@id": "partington",
#         "label": "Partington",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "MNC",
#     "@type": "trade"
#   },
#   {
#     "seq": "004",
#     "location": "England & Wales",
#     "label": "Medway",
#     "includes": [
#       {
#         "@id": "queenborough",
#         "label": "Queenborough",
#         "@type": "seaport"
#       },
#       {
#         "@id": "ridham_dock",
#         "label": "Ridham Dock",
#         "@type": "seaport"
#       },
#       {
#         "@id": "rochester",
#         "label": "Rochester",
#         "@type": "seaport"
#       },
#       {
#         "@id": "sheerness",
#         "label": "Sheerness",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "MED",
#     "@type": "trade"
#   },
#   {
#     "seq": "180",
#     "location": "England & Wales",
#     "label": "Middlesbrough",
#     "includes": [
#       {
#         "@id": "teesport",
#         "label": "Teesport",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "MID",
#     "@type": "trade"
#   },
#   {
#     "seq": "101",
#     "location": "England & Wales",
#     "label": "Milford",
#     "includes": [
#       {
#         "@id": "pembroke_(oils)_so",
#         "label": "Pembroke (Oils) SO",
#         "@type": "seaport"
#       },
#       {
#         "@id": "pembroke_epu",
#         "label": "Pembroke EPU",
#         "@type": "seaport"
#       },
#       {
#         "@id": "pembroke_ferry",
#         "label": "Pembroke Ferry",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "MIL",
#     "@type": "trade"
#   },
#   {
#     "seq": "165",
#     "location": "Scotland",
#     "label": "Montrose",
#     "@id": "MON",
#     "@type": "trade"
#   },
#   {
#     "seq": "105",
#     "location": "England & Wales",
#     "label": "Mostyn",
#     "includes": [
#       {
#         "@id": "rhyl",
#         "label": "Rhyl",
#         "@type": "seaport"
#       },
#       {
#         "@id": "shotton",
#         "label": "Shotton",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "MOS",
#     "@type": "trade"
#   },
#   {
#     "seq": "177",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "newcastle",
#         "label": "Newcastle",
#         "@type": "seaport"
#       },
#       {
#         "@id": "north_shields",
#         "label": "North Shields",
#         "@type": "seaport"
#       },
#       {
#         "@id": "south_shields",
#         "label": "South Shields",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Tyne",
#     "@id": "TYN",
#     "@type": "trade"
#   },
#   {
#     "seq": "026",
#     "location": "England & Wales",
#     "label": "Newhaven",
#     "@id": "NHV",
#     "@type": "trade"
#   },
#   {
#     "seq": "059",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "newlyn",
#         "label": "Newlyn",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Penzance",
#     "@id": "PEN",
#     "@type": "trade"
#   },
#   {
#     "seq": "127",
#     "location": "England & Wales",
#     "label": "Northwich",
#     "@id": "NTH",
#     "@type": "trade"
#   },
#   {
#     "seq": "231",
#     "location": "England & Wales",
#     "label": "Norwich",
#     "@id": "NOR",
#     "@type": "trade"
#   },
#   {
#     "seq": "055",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "padstow",
#         "label": "Padstow",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Plymouth",
#     "@id": "PLY",
#     "@type": "trade"
#   },
#   {
#     "seq": "057",
#     "location": "England & Wales",
#     "label": "Par",
#     "@id": "PAR",
#     "@type": "trade"
#   },
#   {
#     "seq": "163",
#     "location": "Scotland",
#     "label": "Peterhead",
#     "@id": "PHD",
#     "@type": "trade"
#   },
#   {
#     "seq": "051",
#     "location": "England & Wales",
#     "label": "Poole",
#     "@id": "POO",
#     "@type": "trade"
#   },
#   {
#     "seq": "028",
#     "location": "England & Wales",
#     "label": "Portsmouth",
#     "@id": "PTM",
#     "@type": "trade"
#   },
#   {
#     "seq": "493",
#     "comment": "Not to be used when completing declarations.",
#     "includes": [
#       {
#         "@id": "postal_packages",
#         "label": "Postal Packages",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "PPP",
#     "@type": "trade"
#   },
#   {
#     "seq": "006",
#     "location": "England & Wales",
#     "label": "Ramsgate",
#     "@id": "RMG",
#     "@type": "trade"
#   },
#   {
#     "seq": "171",
#     "location": "Scotland",
#     "label": "Rosyth",
#     "@id": "ROS",
#     "@type": "trade"
#   },
#   {
#     "seq": "128",
#     "location": "England & Wales",
#     "label": "Runcorn",
#     "includes": [
#       {
#         "@id": "warrington",
#         "label": "Warrington",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "RUN",
#     "@type": "trade"
#   },
#   {
#     "seq": "183",
#     "location": "England & Wales",
#     "label": "Scarborough",
#     "@id": "SCA",
#     "@type": "trade"
#   },
#   {
#     "seq": "178",
#     "location": "England & Wales",
#     "includes": [
#       {
#         "@id": "seaham",
#         "label": "Seaham",
#         "@type": "seaport"
#       }
#     ],
#     "label": "Sunderland",
#     "@id": "SUN",
#     "@type": "trade"
#   },
#   {
#     "seq": "137",
#     "location": "England & Wales",
#     "label": "Silloth",
#     "@id": "SIL",
#     "@type": "trade"
#   },
#   {
#     "seq": "328",
#     "location": "Channel Islands",
#     "includes": [
#       {
#         "@id": "st_helier",
#         "label": "St Helier",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "JSY",
#     "@type": "trade"
#   },
#   {
#     "seq": "327",
#     "location": "Channel Islands",
#     "includes": [
#       {
#         "@id": "st_peter_port",
#         "label": "St Peter Port",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "GSY",
#     "@type": "trade"
#   },
#   {
#     "seq": "157",
#     "location": "Scotland",
#     "label": "Stornoway",
#     "@id": "STO",
#     "@type": "trade"
#   },
#   {
#     "seq": "009",
#     "location": "England & Wales",
#     "label": "Thames Europort",
#     "@id": "TEP",
#     "@type": "trade"
#   },
#   {
#     "seq": "003",
#     "location": "England & Wales",
#     "label": "Thamesport",
#     "@id": "THP",
#     "@type": "trade"
#   },
#   {
#     "seq": "499",
#     "comment": "Not to be used when completing declarations.",
#     "includes": [
#       {
#         "@id": "unknown_place_of_clearance",
#         "label": "Unknown Place of Clearance",
#         "@type": "seaport"
#       }
#     ],
#     "@id": "XXX",
#     "@type": "trade"
#   },
#   {
#     "seq": "304",
#     "location": "Northern Ireland",
#     "label": "Warrenpoint",
#     "@id": "WPT",
#     "@type": "trade"
#   },
#   {
#     "seq": "182",
#     "location": "England & Wales",
#     "label": "Whitby",
#     "@id": "WTB",
#     "@type": "trade"
#   },
#   {
#     "seq": "135",
#     "location": "England & Wales",
#     "label": "Whitehaven",
#     "@id": "WHV",
#     "@type": "trade"
#   },
#   {
#     "seq": "227",
#     "location": "England & Wales",
#     "label": "Wisbech",
#     "@id": "WIS",
#     "@type": "trade"
#   },
#   {
#     "seq": "136",
#     "location": "England & Wales",
#     "label": "Workington",
#     "@id": "WOR",
#     "@type": "trade"
#   }
# ]

# %% [markdown]
# Put this into JSON-LD.

# %%
seaports_context = {
    "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
    "schema": "http://schema.org/",
    "ports": "https://www.uktradeinfo.com/def/ports#",
    "seq": "ukti:sequence",
    "@base": "https://www.uktradeinfo.com/id/seaports/",
    "includes": {"@reverse": "ports:includedIn"},
    "seaport": "ports:Seaport",
    "trade": "ports:TradeSeaport"
}

with open('out/seaports.jsonld', 'w') as seaport_file:
    json.dump({'@context': seaports_context, '@graph': seaports_list}, seaport_file, indent=2)
